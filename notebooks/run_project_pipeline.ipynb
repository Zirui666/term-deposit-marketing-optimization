# %% [markdown]
# # Predictive Optimization for Term-Deposit Marketing
#
# This notebook runs the project pipeline using the same Stage I and Stage II code structure stored in `src/`.
#
# Before running, place both required CSV files in the `data/` folder:
#
# - `bank-full.csv`
# - `bank_marketing_refined_with_synth_apr (cleaned records).csv`

# %%
from pathlib import Path
PROJECT_ROOT = Path.cwd()
if PROJECT_ROOT.name == 'notebooks':
    PROJECT_ROOT = PROJECT_ROOT.parent
print('Project root:', PROJECT_ROOT)
print('Data folder:', PROJECT_ROOT / 'data')

# %%
import sys
sys.path.insert(0, str(PROJECT_ROOT))
from src.stage_1 import main, run_stage_2

main()
stage2_outputs = run_stage_2()
