# %% [markdown]
# # Predictive Optimization for Term-Deposit Marketing
#
# This notebook runs the organized project pipeline.
#
# Required input files:
# - `00_Raw_Data/bank-full.csv`
# - `10_Data_Clean/bank_marketing_refined_with_synth_apr (cleaned records).csv`
#
# Generated outputs are written to:
# - `20_Data_Exploration/`
# - `30_Modeling_Outputs/`
# - `40_Optimization_Results/`

# %%
from pathlib import Path
PROJECT_ROOT = Path.cwd()
if PROJECT_ROOT.name == 'notebooks':
    PROJECT_ROOT = PROJECT_ROOT.parent
print('Project root:', PROJECT_ROOT)
print('Raw data folder:', PROJECT_ROOT / '00_Raw_Data')
print('Clean data folder:', PROJECT_ROOT / '10_Data_Clean')

# %%
import sys
sys.path.insert(0, str(PROJECT_ROOT))
from src.stage_1 import main, run_stage_2

main()
stage2_outputs = run_stage_2()
